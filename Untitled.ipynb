# %%
from NGDataPortal import Wrapper
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-c7c54df8efc2> in <module>
# ----> 1 from __main__ import Wrapper
#
# ImportError: cannot import name 'Wrapper'
